# %%
import pandas as pd
# Out:
# C:\Users\irem_\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df=pd.read_csv("gender_classifier.csv",encoding="latin1")

# %%
df.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  815719226    False   finalized                   3    10/26/15 23:24
# 1  815719227    False   finalized                   3    10/26/15 23:30
# 2  815719228    False   finalized                   3    10/26/15 23:33
# 3  815719229    False   finalized                   3    10/26/15 23:10
# 4  815719230    False   finalized                   3     10/27/15 1:15
#
#    gender  gender:confidence profile_yn  profile_yn:confidence  \
# 0    male             1.0000        yes                    1.0
# 1    male             1.0000        yes                    1.0
# 2    male             0.6625        yes                    1.0
# 3    male             1.0000        yes                    1.0
# 4  female             1.0000        yes                    1.0
#
#           created  ...                                       profileimage  \
# 0    12/5/13 1:48  ...  https://pbs.twimg.com/profile_images/414342229...
# 1   10/1/12 13:51  ...  https://pbs.twimg.com/profile_images/539604221...
# 2  11/28/14 11:30  ...  https://pbs.twimg.com/profile_images/657330418...
# 3   6/11/09 22:39  ...  https://pbs.twimg.com/profile_images/259703936...
# 4   4/16/14 13:23  ...  https://pbs.twimg.com/profile_images/564094871...
#
#    retweet_count sidebar_color  \
# 0              0        FFFFFF
# 1              0        C0DEED
# 2              1        C0DEED
# 3              0        C0DEED
# 4              0             0
#
#                                                 text tweet_coord tweet_count  \
# 0  Robbie E Responds To Critics After Win Against...         NaN      110964
# 1  ÛÏIt felt like they were my friends and I was...         NaN        7471
# 2  i absolutely adore when louis starts the songs...         NaN        5617
# 3  Hi @JordanSpieth - Looking at the url - do you...         NaN        1693
# 4  Watching Neighbours on Sky+ catching up with t...         NaN       31462
#
#     tweet_created      tweet_id   tweet_location               user_timezone
# 0  10/26/15 12:40  6.587300e+17  main; @Kan1shk3                     Chennai
# 1  10/26/15 12:40  6.587300e+17              NaN  Eastern Time (US & Canada)
# 2  10/26/15 12:40  6.587300e+17           clcncl                    Belgrade
# 3  10/26/15 12:40  6.587300e+17    Palo Alto, CA  Pacific Time (US & Canada)
# 4  10/26/15 12:40  6.587300e+17              NaN                         NaN
#
# [5 rows x 26 columns]

# %%
df=pd.concat([df.gender,df.description],axis=1)

# %%
df.head()
# Out:
#    gender                                        description
# 0    male                              i sing my own rhythm.
# 1    male  I'm the author of novels filled with family dr...
# 2    male                louis whining and squealing and all
# 3    male  Mobile guy.  49ers, Shazam, Google, Kleiner Pe...
# 4  female  Ricky Wilson The Best FRONTMAN/Kaiser Chiefs T...

# %%
df.isnull().sum()
# Out:
# gender           97
# description    3744
# dtype: int64

# %%
df.shape
# Out:
# (20050, 2)

# %%
df.dropna(axis=0,inplace=True)

# %%
df.shape
# Out:
# (16224, 2)

# %%
#katagorik veya ingeter 
df['gender'] = df['gender'].apply(lambda x: 1 if x == "female" else 0)

# %%
df.head()
# Out:
#    gender                                        description
# 0       0                              i sing my own rhythm.
# 1       0  I'm the author of novels filled with family dr...
# 2       0                louis whining and squealing and all
# 3       0  Mobile guy.  49ers, Shazam, Google, Kleiner Pe...
# 4       1  Ricky Wilson The Best FRONTMAN/Kaiser Chiefs T...

# %% [markdown]
# data cleaning

# %%
#regular expression 
import re

# %%
first_prepare=df.description[4]
print(first_prepare)
# Out:
# Ricky Wilson The Best FRONTMAN/Kaiser Chiefs The Best BAND Xxxx Thank you Kaiser Chiefs for an incredible year of gigs and memories to cherish always :) Xxxxxxx

# %%
description = re.sub("[^a-zA-Z]"," ",first_prepare)
print(description)
# burada metini az ye tara ve alfabe dışındakinlarin yerine boşluk ile değiştir
# Out:
# Ricky Wilson The Best FRONTMAN Kaiser Chiefs The Best BAND Xxxx Thank you Kaiser Chiefs for an incredible year of gigs and memories to cherish always    Xxxxxxx

# %%
description=description.lower()#büyük harften küçük harfe çevirme

# %%
print(description)
# Out:
# ricky wilson the best frontman kaiser chiefs the best band xxxx thank you kaiser chiefs for an incredible year of gigs and memories to cherish always    xxxxxxx

# %%
import nltk

# %%
nltk.download("all")
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package bcp47 to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bcp47 is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet2022 to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2022 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     C:\Users\irem_\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
from nltk.corpus import stopwords
description = nltk.word_tokenize(description)

# %%
description
# Out:
# ['ricky',
#  'wilson',
#  'the',
#  'best',
#  'frontman',
#  'kaiser',
#  'chiefs',
#  'the',
#  'best',
#  'band',
#  'xxxx',
#  'thank',
#  'you',
#  'kaiser',
#  'chiefs',
#  'for',
#  'an',
#  'incredible',
#  'year',
#  'of',
#  'gigs',
#  'and',
#  'memories',
#  'to',
#  'cherish',
#  'always',
#  'xxxxxxx']

# %%
#gereksiz kelimleri çıkar 
description =[word for word in description if not word in set (stopwords.words("english")) ]

# %%
description
# Out:
# ['ricky',
#  'wilson',
#  'best',
#  'frontman',
#  'kaiser',
#  'chiefs',
#  'best',
#  'band',
#  'xxxx',
#  'thank',
#  'kaiser',
#  'chiefs',
#  'incredible',
#  'year',
#  'gigs',
#  'memories',
#  'cherish',
#  'always',
#  'xxxxxxx']

# %%
#iyelik eki  ve mastar ekleri olanları düzeltemk kökü bulamak lemazation 
import nltk as nlp 
lemma=nlp.WordNetLemmatizer()
description = [lemma.lemmatize(word)for word  in description]

description=" ".join(description)

# %%
description
# Out:
# 'ricky wilson best frontman kaiser chief best band xxxx thank kaiser chief incredible year gig memory cherish always xxxxxxx'

# %%
descriptin_list=[]
for  description in df.description:
    description = re.sub("[^a-zA-Z]"," ",description)
    description=description.lower()
    description = nltk.word_tokenize(description)
    description =[word for word in description if not word in set (stopwords.words("english")) ]
    lemma=nlp.WordNetLemmatizer()
    description = [lemma.lemmatize(word)for word  in description]

    description=" ".join(description)
    descriptin_list.append(description)

# %%
from sklearn.feature_extraction.text import CountVectorizer
max_features=622
count_Vectorizer = CountVectorizer(max_features=max_features)
sparce_martix = count_Vectorizer.fit_transform(descriptin_list).toarray()
print("en sık kullanılan :{} kelimeler :{}".format(max_features,count_Vectorizer.get_feature_names_out()))
# Out:
# en sık kullanılan :622 kelimeler :['account' 'across' 'activist' 'actor' 'addict' 'adult' 'adventure'
#  'advocate' 'also' 'alum' 'always' 'amazing' 'america' 'american'
#  'analyst' 'angel' 'animal' 'anime' 'anti' 'anything' 'app' 'area'
#  'around' 'arsenal' 'art' 'artist' 'as' 'ask' 'aspiring' 'author' 'award'
#  'away' 'awesome' 'baby' 'back' 'bad' 'band' 'baseball' 'based'
#  'basketball' 'beautiful' 'beauty' 'beer' 'believe' 'best' 'better' 'big'
#  'bio' 'bit' 'bitch' 'black' 'blessed' 'blog' 'blogger' 'blue' 'book'
#  'booking' 'born' 'bot' 'boy' 'brand' 'breaking' 'bringing' 'brother'
#  'building' 'business' 'buy' 'ca' 'call' 'canada' 'car' 'card' 'care'
#  'cat' 'cause' 'ceo' 'certified' 'change' 'channel' 'check' 'chicago'
#  'chief' 'child' 'christ' 'christian' 'city' 'class' 'club' 'co' 'coach'
#  'coffee' 'college' 'com' 'come' 'comic' 'coming' 'communication'
#  'community' 'company' 'computer' 'conservative' 'consultant' 'contact'
#  'content' 'continuous' 'control' 'cool' 'could' 'country' 'county'
#  'cover' 'crazy' 'create' 'creative' 'creator' 'culture' 'current'
#  'currently' 'customer' 'cute' 'dad' 'daily' 'dance' 'data' 'day' 'de'
#  'deal' 'dedicated' 'design' 'designer' 'developer' 'development' 'die'
#  'digital' 'direction' 'director' 'disney' 'dj' 'dm' 'dog' 'dont' 'dream'
#  'dreamer' 'eat' 'ed' 'editor' 'education' 'el' 'else' 'email' 'en' 'end'
#  'endorsement' 'engineer' 'english' 'enjoy' 'enough' 'entertainment'
#  'enthusiast' 'entrepreneur' 'estate' 'etc' 'even' 'event' 'ever' 'every'
#  'everyday' 'everyone' 'everything' 'ex' 'experience' 'expert' 'eye'
#  'facebook' 'fall' 'family' 'fan' 'fanatic' 'fantasy' 'fashion' 'father'
#  'favorite' 'fc' 'feed' 'feel' 'feminist' 'film' 'financial' 'find'
#  'finding' 'first' 'fitness' 'follow' 'followed' 'follower' 'follows'
#  'food' 'football' 'forever' 'former' 'founder' 'free' 'freelance'
#  'friend' 'fuck' 'fucking' 'full' 'fun' 'funny' 'future' 'game' 'gamer'
#  'gaming' 'gay' 'geek' 'general' 'get' 'girl' 'give' 'global' 'gmail' 'go'
#  'god' 'going' 'gon' 'good' 'google' 'got' 'government' 'graduate'
#  'graphic' 'great' 'green' 'group' 'guy' 'hair' 'hand' 'happiness' 'happy'
#  'hard' 'harry' 'hate' 'head' 'health' 'heart' 'hell' 'hello' 'help'
#  'helping' 'hey' 'hi' 'high' 'hip' 'history' 'hockey' 'home' 'hop' 'hope'
#  'host' 'hot' 'house' 'http' 'huge' 'human' 'husband' 'idea' 'ig' 'im'
#  'improve' 'independent' 'industry' 'info' 'information' 'inquiry'
#  'inspirational' 'insta' 'instagram' 'interested' 'international'
#  'internet' 'jesus' 'job' 'john' 'join' 'joke' 'journalist' 'junkie'
#  'justice' 'justin' 'keep' 'kid' 'kind' 'king' 'know' 'la' 'lady' 'last'
#  'latest' 'laugh' 'law' 'le' 'lead' 'leader' 'leading' 'league' 'learn'
#  'learning' 'left' 'let' 'life' 'lifestyle' 'light' 'like' 'link' 'little'
#  'live' 'living' 'local' 'london' 'long' 'look' 'looking' 'lost' 'lot'
#  'louis' 'love' 'lover' 'loving' 'made' 'magazine' 'major' 'make' 'maker'
#  'making' 'man' 'management' 'manager' 'many' 'map' 'marketing' 'married'
#  'master' 'matter' 'may' 'mean' 'medium' 'meet' 'member' 'men' 'met'
#  'metal' 'mi' 'mind' 'mine' 'miss' 'mobile' 'model' 'mom' 'money' 'mostly'
#  'mother' 'movie' 'much' 'mufc' 'mum' 'music' 'musician' 'must' 'na'
#  'name' 'nation' 'national' 'nature' 'need' 'nerd' 'network' 'never' 'new'
#  'news' 'nfl' 'nice' 'night' 'non' 'north' 'nothing' 'nsfw' 'obsessed'
#  'offer' 'official' 'oh' 'old' 'one' 'online' 'open' 'opinion' 'order'
#  'organization' 'others' 'outlook' 'owner' 'page' 'part' 'partner' 'party'
#  'passion' 'passionate' 'peace' 'people' 'perfect' 'person' 'personal'
#  'pet' 'photo' 'photographer' 'photography' 'pic' 'picture' 'pizza'
#  'place' 'play' 'player' 'playing' 'please' 'pm' 'podcast' 'politics'
#  'pop' 'positive' 'post' 'power' 'pr' 'president' 'pretty' 'price'
#  'princess' 'pro' 'probably' 'producer' 'product' 'prof' 'professional'
#  'program' 'project' 'promoting' 'proud' 'provide' 'providing' 'public'
#  'purpose' 'quality' 'que' 'queen' 'question' 'radio' 'random' 'read'
#  'reader' 'reading' 'real' 'really' 'reason' 'red' 'related' 'reporter'
#  'research' 'resource' 'retired' 'retweets' 'review' 'right' 'rip' 'rock'
#  'rp' 'rt' 'run' 'runner' 'running' 'sale' 'say' 'sc' 'school' 'science'
#  'season' 'seattle' 'secret' 'see' 'self' 'send' 'senior' 'series'
#  'service' 'sex' 'sexy' 'share' 'shit' 'shop' 'short' 'show' 'simple'
#  'since' 'singer' 'single' 'site' 'small' 'smile' 'snapchat' 'so' 'social'
#  'software' 'solution' 'someone' 'something' 'sometimes' 'son' 'song'
#  'songwriter' 'soul' 'sound' 'source' 'south' 'space' 'speaker' 'special'
#  'specialist' 'sport' 'st' 'star' 'start' 'state' 'station' 'stay' 'still'
#  'stop' 'story' 'street' 'strong' 'student' 'stuff' 'style' 'subscribe'
#  'success' 'sun' 'super' 'support' 'supporter' 'take' 'talk' 'tea'
#  'teacher' 'team' 'tech' 'technology' 'tell' 'th' 'thing' 'think'
#  'thought' 'time' 'tip' 'today' 'together' 'top' 'town' 'trainer'
#  'training' 'travel' 'true' 'truth' 'try' 'trying' 'tv' 'tweet' 'tweeting'
#  'tweetmyjobs' 'twitter' 'two' 'type' 'uk' 'united' 'university' 'update'
#  'usa' 'use' 'video' 'view' 'visit' 'voice' 'wan' 'want' 'war' 'watch'
#  'way' 'weather' 'web' 'website' 'welcome' 'well' 'west' 'whatever'
#  'white' 'wife' 'wine' 'winner' 'winning' 'wish' 'without' 'woman' 'word'
#  'work' 'working' 'world' 'would' 'write' 'writer' 'writing' 'year' 'yes'
#  'yo' 'york' 'young' 'youtube' 'youtuber']

# %%
y = df.iloc[:,0].values   # male or female classes
X = sparce_martix

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.1, random_state = 42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
#from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.model_selection import cross_val_score
#accuaracy
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# %%
def model_classification(X,y):
    '''
    X: independent variable
    y: dependent variable
    return best model and its accuracy
    '''
    x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)
    models = [GaussianNB(),BernoulliNB(),LogisticRegression(),RandomForestClassifier(), 
              GradientBoostingClassifier()]
    results=[]
    for model in models:
        model.fit(x_train,y_train)
        model_predict=model.predict(x_test)
        print("Model: ",model)
        print("Model Accuracy: ",accuracy_score(model_predict,y_test))
        print("Model Confusion Matrix: ",confusion_matrix(model_predict,y_test),"\n")
        print("Model Classification Report: ",classification_report(model_predict,y_test))
        print("-"*50)
        results.append(accuracy_score(model_predict,y_test))
    #best model
    best_model=models[results.index(max(results))]
    print("Best Model: ",best_model)
    print("Best Model Accuracy: ",max(results))
    models=pd.DataFrame({
        'Model':['GaussianNB','BernoulliNB','LogisticRegression','RandomForestClassifier', 'GradientBoostingClassifier', 'KNeighborsClassifier'],
        'Score':results})
    print(models.sort_values(by='Score', ascending=False, ignore_index=True))
    return best_model,max(results), confusion_matrix(model_predict,y_test)

# %%
model_classification(X,y)
# Out:
# Model:  GaussianNB()
# Model Accuracy:  0.590797041906327
# Model Confusion Matrix:  [[1454  258]
#  [1734 1422]]
#
# Model Classification Report:                precision    recall  f1-score   support
#
#            0       0.46      0.85      0.59      1712
#            1       0.85      0.45      0.59      3156
#
#     accuracy                           0.59      4868
#    macro avg       0.65      0.65      0.59      4868
# weighted avg       0.71      0.59      0.59      4868
#
# --------------------------------------------------
# Model:  BernoulliNB()
# Model Accuracy:  0.6661873459326212
# Model Confusion Matrix:  [[2101  538]
#  [1087 1142]]
#
# Model Classification Report:                precision    recall  f1-score   support
#
#            0       0.66      0.80      0.72      2639
#            1       0.68      0.51      0.58      2229
#
#     accuracy                           0.67      4868
#    macro avg       0.67      0.65      0.65      4868
# weighted avg       0.67      0.67      0.66      4868
#
# --------------------------------------------------
# Model:  LogisticRegression()
# Model Accuracy:  0.6723500410846344
# Model Confusion Matrix:  [[2702 1109]
#  [ 486  571]]
#
# Model Classification Report:                precision    recall  f1-score   support
#
#            0       0.85      0.71      0.77      3811
#            1       0.34      0.54      0.42      1057
#
#     accuracy                           0.67      4868
#    macro avg       0.59      0.62      0.59      4868
# weighted avg       0.74      0.67      0.70      4868
#
# --------------------------------------------------
# Model:  RandomForestClassifier()
# Model Accuracy:  0.678923582580115
# Model Confusion Matrix:  [[2641 1016]
#  [ 547  664]]
#
# Model Classification Report:                precision    recall  f1-score   support
#
#            0       0.83      0.72      0.77      3657
#            1       0.40      0.55      0.46      1211
#
#     accuracy                           0.68      4868
#    macro avg       0.61      0.64      0.62      4868
# weighted avg       0.72      0.68      0.69      4868
#
# --------------------------------------------------
# Model:  GradientBoostingClassifier()
# Model Accuracy:  0.6702958093672966
# Model Confusion Matrix:  [[3120 1537]
#  [  68  143]]
#
# Model Classification Report:                precision    recall  f1-score   support
#
#            0       0.98      0.67      0.80      4657
#            1       0.09      0.68      0.15       211
#
#     accuracy                           0.67      4868
#    macro avg       0.53      0.67      0.47      4868
# weighted avg       0.94      0.67      0.77      4868
#
# --------------------------------------------------
# Best Model:  RandomForestClassifier()
# Best Model Accuracy:  0.678923582580115
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 model_classification(X,y)
#
# Cell In[47], line 24, in model_classification(X, y)
#      22 print("Best Model: ",best_model)
#      23 print("Best Model Accuracy: ",max(results))
# ---> 24 models=pd.DataFrame({
#      25     'Model':['GaussianNB','BernoulliNB','LogisticRegression','RandomForestClassifier', 'GradientBoostingClassifier', 'KNeighborsClassifier'],
#      26     'Score':results})
#      27 print(models.sort_values(by='Score', ascending=False, ignore_index=True))
#      28 return best_model,max(results), confusion_matrix(model_predict,y_test)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:767, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     761     mgr = self._init_mgr(
#     762         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     763     )
#     765 elif isinstance(data, dict):
#     766     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 767     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     768 elif isinstance(data, ma.MaskedArray):
#     769     from numpy.ma import mrecords
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\internals\construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length
